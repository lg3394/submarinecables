# %% [markdown]
# <h1>Submarine cable data scraping</h1>
# This script fetches and analyzes data about submarine cables that were built and became ready for service between the years 2010 and 2024. It performs the following tasks:
#
# 1. Retrieves data for each year from an API.
# 2. Extracts the cable name and the year they became operational.
# 3. Saves the consolidated data to a CSV file.
# 4. Calculates the number of cables finalized per year and saves this summary to another CSV file.

# %%
import requests

# I start by scraping the URL for the cables built in 2010 to take a look at the dataset
url = "https://www.submarinecablemap.com/api/v3/ready-for-service/2010.json"

response = requests.get(url)

data = response.json()

data
# Out:
# {'id': '2010',
#  'name': '2010',
#  'landing_points': ['chindini-comoros',
#   'mutsamudu-comoros',
#   'fomboni-moheli-comoros',
#   'haramous-djibouti',
#   'mombasa-kenya',
#   'dar-es-salaam-tanzania',
#   'maputo-mozambique',
#   'toliara-madagascar',
#   'mtunzini-south-africa',
#   'port-sudan-sudan',
#   'moroni-comoros',
#   'mogadishu-somalia',
#   'lagos-nigeria',
#   'bude-united-kingdom',
#   'accra-ghana',
#   'majuro-marshall-islands',
#   'kwajalein-marshall-islands',
#   'pohnpei-micronesia',
#   'piti-guam',
#   'kawaihae-hi-united-states',
#   'papenoo-french-polynesia',
#   'vaitape-french-polynesia',
#   'uturoa-french-polynesia',
#   'moorea-french-polynesia',
#   'huahine-french-polynesia',
#   'mumbai-india',
#   'alexandria-egypt',
#   'suez-egypt',
#   'karachi-pakistan',
#   'fujairah-united-arab-emirates',
#   'catania-italy',
#   'tripoli-lebanon',
#   'marseille-france',
#   'jeddah-saudi-arabia',
#   'pontianak-indonesia',
#   'banjarmasin-indonesia',
#   'ketapang-indonesia',
#   'sangata-indonesia',
#   'beculuk-indonesia',
#   'mataram-indonesia',
#   'denpasar-indonesia',
#   'gianyar-indonesia',
#   'toweli-indonesia',
#   'pankalan-indonesia',
#   'konstanz-germany',
#   'meersburg-germany',
#   'seixal-portugal',
#   'abidjan-cte-divoire',
#   'dakar-senegal',
#   'iojima-japan',
#   'takeshima-japan',
#   'kuroshima-japan',
#   'makurazaki-japan',
#   'kuala-tungkal-indonesia',
#   'batam-indonesia',
#   'sakra-island-singapore',
#   'san-andres-colombia',
#   'tolu-colombia',
#   'chaguaramas-trinidad-and-tobago',
#   'georgetown-guyana',
#   'totness-suriname',
#   'tobruk-libya',
#   'el-quawef-libya',
#   'nesna-norway',
#   'utskarpen-norway',
#   'hemnesberget-norway',
#   'mo-i-rana-norway',
#   'chikura-japan',
#   'redondo-beach-ca-united-states'],
#  'cables': [{'id': 'comoros-domestic-cable-system',
#    'name': 'Comoros Domestic Cable System',
#    'rfs_year': 2010,
#    'is_planned': False},
#   {'id': 'eastern-africa-submarine-system-eassy',
#    'name': 'Eastern Africa Submarine System (EASSy)',
#    'rfs_year': 2010,
#    'is_planned': False},
#   {'id': 'glo-1', 'name': 'Glo-1', 'rfs_year': 2010, 'is_planned': False},
#   {'id': 'hantru1-cable-system',
#    'name': 'HANTRU1 Cable System',
#    'rfs_year': 2010,
#    'is_planned': False},
#   {'id': 'honotua', 'name': 'Honotua', 'rfs_year': 2010, 'is_planned': False},
#   {'id': 'imewe', 'name': 'IMEWE', 'rfs_year': 2010, 'is_planned': False},
#   {'id': 'jaka2ladema',
#    'name': 'JaKa2LaDeMa',
#    'rfs_year': 2010,
#    'is_planned': False},
#   {'id': 'konstanz-meersburg',
#    'name': 'Konstanz-Meersburg',
#    'rfs_year': 2010,
#    'is_planned': False},
#   {'id': 'mainone', 'name': 'MainOne', 'rfs_year': 2010, 'is_planned': False},
#   {'id': 'mishima-village',
#    'name': 'Mishima Village',
#    'rfs_year': 2010,
#    'is_planned': False},
#   {'id': 'pgascom', 'name': 'PGASCOM', 'rfs_year': 2010, 'is_planned': False},
#   {'id': 'san-andres-isla-tolu-submarine-cable-sait',
#    'name': 'San Andres Isla Tolu Submarine Cable (SAIT)',
#    'rfs_year': 2010,
#    'is_planned': False},
#   {'id': 'suriname-guyana-submarine-cable-system-sg-scs',
#    'name': 'Suriname-Guyana Submarine Cable System (SG-SCS)',
#    'rfs_year': 2010,
#    'is_planned': False},
#   {'id': 'tobrok-emasaed-cable-system',
#    'name': 'Tobrok-Emasaed Cable System',
#    'rfs_year': 2010,
#    'is_planned': False},
#   {'id': 'tverrlinken',
#    'name': 'Tverrlinken',
#    'rfs_year': 2010,
#    'is_planned': False},
#   {'id': 'unityeac-pacific',
#    'name': 'Unity/EAC-Pacific',
#    'rfs_year': 2010,
#    'is_planned': False}]}

# %%
import pandas as pd

df = pd.json_normalize(data['cables'])

# %%
# I calculate the length of the df to see if it matches the number of cables I've manually counted listed in the URL.
len(df)
# Out:
# 16

# %%
# I take a look at the cables
df.head(16)
# Out:
#                                                id  \
# 0                   comoros-domestic-cable-system
# 1           eastern-africa-submarine-system-eassy
# 2                                           glo-1
# 3                            hantru1-cable-system
# 4                                         honotua
# 5                                           imewe
# 6                                     jaka2ladema
# 7                              konstanz-meersburg
# 8                                         mainone
# 9                                 mishima-village
# 10                                        pgascom
# 11      san-andres-isla-tolu-submarine-cable-sait
# 12  suriname-guyana-submarine-cable-system-sg-scs
# 13                    tobrok-emasaed-cable-system
# 14                                    tverrlinken
# 15                               unityeac-pacific
#
#                                                name  rfs_year  is_planned
# 0                     Comoros Domestic Cable System      2010       False
# 1           Eastern Africa Submarine System (EASSy)      2010       False
# 2                                             Glo-1      2010       False
# 3                              HANTRU1 Cable System      2010       False
# 4                                           Honotua      2010       False
# 5                                             IMEWE      2010       False
# 6                                       JaKa2LaDeMa      2010       False
# 7                                Konstanz-Meersburg      2010       False
# 8                                           MainOne      2010       False
# 9                                   Mishima Village      2010       False
# 10                                          PGASCOM      2010       False
# 11      San Andres Isla Tolu Submarine Cable (SAIT)      2010       False
# 12  Suriname-Guyana Submarine Cable System (SG-SCS)      2010       False
# 13                      Tobrok-Emasaed Cable System      2010       False
# 14                                      Tverrlinken      2010       False
# 15                                Unity/EAC-Pacific      2010       False

# %%
df['name'],['rfs_year']
# Out:
# (0                       Comoros Domestic Cable System
#  1             Eastern Africa Submarine System (EASSy)
#  2                                               Glo-1
#  3                                HANTRU1 Cable System
#  4                                             Honotua
#  5                                               IMEWE
#  6                                         JaKa2LaDeMa
#  7                                  Konstanz-Meersburg
#  8                                             MainOne
#  9                                     Mishima Village
#  10                                            PGASCOM
#  11        San Andres Isla Tolu Submarine Cable (SAIT)
#  12    Suriname-Guyana Submarine Cable System (SG-SCS)
#  13                        Tobrok-Emasaed Cable System
#  14                                        Tverrlinken
#  15                                  Unity/EAC-Pacific
#  Name: name, dtype: object,
#  ['rfs_year'])

# %%
# Now that I know that the data looks like, I can write code that allows me to loop through the URLs from 2010 to 2024 and fetch the data so I can download it.
years = range(2010, 2025)
base_url = "https://www.submarinecablemap.com/api/v3/ready-for-service/{}.json"

# %%
# Creating an empty list to store the data
all_cables = []

# %%
# Loop through the years
# Loop through the years and fetch data
for year in years:
    url = base_url.format(year)
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        # Normalize the JSON data to a DataFrame
        df = pd.json_normalize(data['cables'])
        # Select only the desired columns
        df = df[['name', 'rfs_year']]
        df = df.rename(columns={'rfs_year': 'year'})
        all_cables.append(df)
    else:
        print(f"Failed to fetch data for year {year}")

# %%
all_cables
# Out:
# [                                               name  year
#  0                     Comoros Domestic Cable System  2010
#  1           Eastern Africa Submarine System (EASSy)  2010
#  2                                             Glo-1  2010
#  3                              HANTRU1 Cable System  2010
#  4                                           Honotua  2010
#  5                                             IMEWE  2010
#  6                                       JaKa2LaDeMa  2010
#  7                                Konstanz-Meersburg  2010
#  8                                           MainOne  2010
#  9                                   Mishima Village  2010
#  10                                          PGASCOM  2010
#  11      San Andres Isla Tolu Submarine Cable (SAIT)  2010
#  12  Suriname-Guyana Submarine Cable System (SG-SCS)  2010
#  13                      Tobrok-Emasaed Cable System  2010
#  14                                      Tverrlinken  2010
#  15                                Unity/EAC-Pacific  2010,
#                                                   name  year
#  0                                        Bicentenario  2011
#  1   Cabo Verde Telecom Domestic Submarine Cable Ph...  2011
#  2                                            Canalink  2011
#  3                                             Ceiba-1  2011
#  4                                           East-West  2011
#  5                             Energinet Laeso-Varberg  2011
#  6                              Energinet Lyngsa-Laeso  2011
#  7                          Europe India Gateway (EIG)  2011
#  8                                          FISH North  2011
#  9                                                Hawk  2011
#  10                             Hokkaido-Rebun-Rishiri  2011
#  11                                             JAVALI  2011
#  12                 Mataram Kupang Cable System (MKCS)  2011
#  13                                 Minamidaito Island  2011
#  14                            Ogasawara Cable Network  2011
#  15                                           Pencan-8  2011
#  16                                             Romulo  2011
#  17                       Saudi Arabia-Sudan-2 (SAS-2)  2011
#  18       TE North/TGN-Eurasia/SEACOM/Alexandros/Medex  2011
#  19                                          Turcyos-2  2011,
#                                                   name  year
#  0                        Africa Coast to Europe (ACE)  2012
#  1                  Alaska United Turnagain Arm (AUTA)  2012
#  2                                              ALBA-1  2012
#  3                   ARSAT Submarine Fiber Optic Cable  2012
#  4   Asia Submarine-cable Express (ASE)/Cahaya Mala...  2012
#  5                              CeltixConnect-1 (CC-1)  2012
#  6                  Cross-Straits Cable Network (CSCN)  2012
#  7                              Dhiraagu Cable Network  2012
#  8                               Emerald Bridge Fibres  2012
#  9                                         Geo-Eirgrid  2012
#  10  Gulf Bridge International Cable System/Middle ...  2012
#  11       Jakarta-Bangka-Bintan-Batam-Singapore (B3JS)  2012
#  12                                              Jonah  2012
#  13                       Libreville-Port Gentil Cable  2012
#  14               Lower Indian Ocean Network 2 (LION2)  2012
#  15                  Pishgaman Oman Iran (POI) Network  2012
#  16            Seychelles to East Africa System (SEAS)  2012
#  17                                      Tamares North  2012
#  18                                      Tata TGN-Gulf  2012
#  19                                           TERRA SW  2012
#  20                                               TT-1  2012
#  21                    West Africa Cable System (WACS)  2012,
#                                                   name  year
#  0   B2JS (Jakarta-Bangka-Batam-Singapore) Cable Sy...  2013
#  1      Boracay-Palawan Submarine Cable System (BPSCS)  2013
#  2                  Guam Okinawa Kyushu Incheon (GOKI)  2013
#  3                       Java Bali Cable System (JBCS)  2013
#  4   Lazaro Cardenas-Manzanillo Santiago Submarine ...  2013
#  5                                          OMRAN/EPEG  2013
#  6                    Saba, Statia Cable System (SSCS)  2013
#  7                                            Silphium  2013
#  8                    Southeast Asia-Japan Cable (SJC)  2013
#  9             Taiwan Penghu Kinmen Matsu No.3 (TPKM3)  2013
#  10                    Taiwan Strait Express-1 (TSE-1)  2013
#  11                                        Tonga Cable  2013,
#                                                   name  year
#  0      America Movil Submarine Cable System-1 (AMX-1)  2014
#  1     BT Highlands and Islands Submarine Cable System  2014
#  2                                               Didon  2014
#  3                           Flores-Corvo Cable System  2014
#  4                  Interchange Cable Network 1 (ICN1)  2014
#  5                               Isles of Scilly Cable  2014
#  6                     Jambi-Batam Cable System (JIBA)  2014
#  7                                  Kerch Strait Cable  2014
#  8   Middle East North Africa (MENA) Cable System/G...  2014
#  9                         Palawan-Iloilo Cable System  2014
#  10                                            PNG LNG  2014
#  11                                           POSEIDON  2014
#  12                             Roquetas-Melilla (CAM)  2014
#  13                                        Skagerrak 4  2014
#  14                Sumatera Bangka Cable System (SBCS)  2014
#  15                  Tarakan Selor Cable System (TSCS)  2014,
#                                                name  year
#  0                                      EXA Express  2015
#  1                            FOS Quellon-Chacabuco  2015
#  2                Luwuk Tutuyan Cable System (LTCS)  2015
#  3                       Malta-Italy Interconnector  2015
#  4  Nigeria Cameroon Submarine Cable System (NCSCS)  2015
#  5            Pacific Caribbean Cable System (PCCS)  2015
#  6                      Segunda FOS Canal de Chacao  2015
#  7                                   SMPCS Packet-1  2015
#  8                                   SMPCS Packet-2  2015
#  9                                     Zayo Festoon  2015,
#                                                   name  year
#  0                                               AEC-1  2016
#  1                          Asia Pacific Gateway (APG)  2016
#  2                                              Avassa  2016
#  3                                               BALOK  2016
#  4                         Bay of Bengal Gateway (BBG)  2016
#  5                                     Bodo-Rost Cable  2016
#  6                                             C-Lion1  2016
#  7                     Far East Submarine Cable System  2016
#  15                                PEACE Cable  2022
#  16          Petropavlovsk-Kamchatsky - Anadyr  2022
#  17                              Polar Express  2022
#  18                Scotland-Northern Ireland 3  2022
#  19                Scotland-Northern Ireland 4  2022
#  20                        Southern Cross NEXT  2022
#  21  Submarine Cable in the Philippines (SCiP)  2022
#  22                                     Thetis  2022
#  23                             Yuza-Tobishima  2022
#  24                                       Zeus  2022,
#                                                   name  year
#  0                                              Amitie  2023
#  1                                              ARIMAO  2023
#  2            Biznet Nusantara Cable System-1 (BNCS-1)  2023
#  3                                                Blue  2023
#  4               Darwin-Jakarta-Singapore Cable (DJSC)  2023
#  5                                             Equiano  2023
#  6                                Hokkaido-Akita Cable  2023
#  7                                              Ionian  2023
#  8                                                IRIS  2023
#  9                                            Jalapati  2023
#  10                                           Jeju-Udo  2023
#  11                                            Medloop  2023
#  12                                           Mercator  2023
#  13                                        Natitua Sud  2023
#  14                                            Norfest  2023
#  15                       Norte Conectado (Infovia 01)  2023
#  16                                           Patara-2  2023
#  17  Philippine Domestic Submarine Cable Network (P...  2023
#  18                                         R100 North  2023
#  19                                            Red2Med  2023
#  20                                       Saudi Vision  2023
#  21                                            SEALink  2023
#  22  Senegal Horn of Africa Regional Express (SHARE...  2023
#  23                                                 T3  2023
#  24                                  Tautira-Teahupo'o  2023
#  25                                        TKO Connect  2023
#  26                            Tokelau Submarine Cable  2023
#  27                                              Topaz  2023
#  28                       Trans Adriatic Express (TAE)  2023
#  29                                        Ultramar GE  2023
#  30                                                UMO  2023
#  31                Unitel North Submarine Cable (UNSC)  2023
#  32                                                YUI  2023,
#                                              name  year
#  0                                        2Africa  2024
#  1                        Asia Direct Cable (ADC)  2024
#  2                                         Aurora  2024
#  3                                Connected Coast  2024
#  4                                  Deep Blue One  2024
#  5   Domestic Submarine Cable of Maldives (DSCoM)  2024
#  6                                       EAUFON 2  2024
#  7                                          Iceni  2024
#  8                        India Asia Xpress (IAX)  2024
#  9                             Isle Au Haut Cable  2024
#  10                             Kangaroo Island 2  2024
#  11          Kochi-Lakshadweep Islands (KLI-SOFC)  2024
#  12                                          MIST  2024
#  13                  Norte Conectado (Infovia 03)  2024
#  14                            Piano Isole Minori  2024
#  15                                 SEALink South  2024]

# %%
# Check whether all years are in the df
len(all_cables)
# Out:
# 15

# %%
# Put together all the data into a single df
final_allcables = pd.concat(all_cables, ignore_index=True)

# %%
# Save the df to an csv file
output_file = "submarine_cables_2010_2024.csv"
final_allcables.to_csv(output_file, index=False)

# %%
# The list of cable names and year when they were built is ultimately not what I want to visualize. I will now write code that will count the number of cables built per year and createas a new df I can download as a separate csv file.
cables_per_year = final_allcables['year'].value_counts().reset_index()
cables_per_year.columns = ['year', 'cable_count']
cables_per_year = cables_per_year.sort_values('year')

# %%
count_output_file = "cables_per_year_2010_2024.csv"
cables_per_year.to_csv(count_output_file, index=False)
